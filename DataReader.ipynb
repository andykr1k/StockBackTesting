# %%
import pandas_datareader.data as web
import datetime
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
start = datetime.datetime(2017,1,1)
end = datetime.datetime(2022,9,29)

# %%
googl = web.DataReader("GOOGL", "yahoo", start, end)
aapl = web.DataReader("AAPL", "yahoo", start, end)
tsla = web.DataReader("TSLA", "yahoo", start, end)
msft = web.DataReader("MSFT", "yahoo", start, end)
spy = web.DataReader("SPY", "yahoo", start, end)

# %%
googl.head()
# Out:
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2017-01-03  40.571999  39.844501  40.030998  40.400501  39180000.0  40.400501
# 2017-01-04  40.671501  40.205502  40.494499  40.388500  30306000.0  40.388500
# 2017-01-05  40.687000  40.296001  40.375000  40.651001  26810000.0  40.651001
# 2017-01-06  41.448002  40.575001  40.749500  41.260502  40342000.0  41.260502
# 2017-01-09  41.521500  41.081001  41.318501  41.359001  28178000.0  41.359001

# %%
aapl.head()
# Out:
#                  High        Low       Open      Close       Volume  Adj Close
# Date
# 2017-01-03  29.082500  28.690001  28.950001  29.037500  115127600.0  27.219841
# 2017-01-04  29.127501  28.937500  28.962500  29.004999   84472400.0  27.189369
# 2017-01-05  29.215000  28.952499  28.980000  29.152500   88774400.0  27.327633
# 2017-01-06  29.540001  29.117500  29.195000  29.477501  127007600.0  27.632294
# 2017-01-09  29.857500  29.485001  29.487499  29.747499  134247600.0  27.885389

# %%
tsla.head()
# Out:
#                  High        Low       Open      Close       Volume  Adj Close
# Date
# 2017-01-03  14.688667  14.064000  14.324000  14.466000   88849500.0  14.466000
# 2017-01-04  15.200000  14.287333  14.316667  15.132667  168202500.0  15.132667
# 2017-01-05  15.165333  14.796667  15.094667  15.116667   88675500.0  15.116667
# 2017-01-06  15.354000  15.030000  15.128667  15.267333   82918500.0  15.267333
# 2017-01-09  15.461333  15.200000  15.264667  15.418667   59692500.0  15.418667

# %%
msft.head()
# Out:
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2017-01-03  62.840000  62.130001  62.790001  62.580002  20694100.0  57.807823
# 2017-01-04  62.750000  62.119999  62.480000  62.299999  21340000.0  57.549179
# 2017-01-05  62.660000  62.029999  62.189999  62.299999  24876000.0  57.549179
# 2017-01-06  63.150002  62.040001  62.299999  62.840000  19922900.0  58.048000
# 2017-01-09  63.080002  62.540001  62.759998  62.639999  20382700.0  57.863243

# %%
spy.head()
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2017-01-03  225.830002  223.880005  225.039993  225.240005  91366500.0
# 2017-01-04  226.750000  225.610001  225.619995  226.580002  78744400.0
# 2017-01-05  226.580002  225.479996  226.270004  226.399994  78379000.0
# 2017-01-06  227.750000  225.899994  226.529999  227.210007  71559900.0
# 2017-01-09  227.070007  226.419998  226.910004  226.460007  46939700.0
#
#              Adj Close
# Date
# 2017-01-03  203.788071
# 2017-01-04  205.000443
# 2017-01-05  204.837540
# 2017-01-06  205.570404
# 2017-01-09  204.891876

# %%
spy["Close"].plot(label='Spy', figsize=(12,6))
tsla["Close"].plot(label='Tesla')
aapl["Close"].plot(label='Apple')
googl["Close"].plot(label='Google')
msft["Close"].plot(label='Microsoft')
plt.legend()

# %%
spy["Volume"].plot(label='Spy', figsize=(12,6))
tsla["Volume"].plot(label='Tesla')
aapl["Volume"].plot(label='Apple')
googl["Volume"].plot(label='Google')
msft["Volume"].plot(label='Microsoft')
plt.legend()

# %%
spy['Total $ Traded'] = spy['Close'] * spy['Volume']
aapl['Total $ Traded'] = aapl['Close'] * aapl['Volume']
msft['Total $ Traded'] = msft['Close'] * msft['Volume']
googl['Total $ Traded'] = googl['Close'] * googl['Volume']
tsla['Total $ Traded'] = tsla['Close'] * tsla['Volume']
spy.head()
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2017-01-03  225.830002  223.880005  225.039993  225.240005  91366500.0
# 2017-01-04  226.750000  225.610001  225.619995  226.580002  78744400.0
# 2017-01-05  226.580002  225.479996  226.270004  226.399994  78379000.0
# 2017-01-06  227.750000  225.899994  226.529999  227.210007  71559900.0
# 2017-01-09  227.070007  226.419998  226.910004  226.460007  46939700.0
#
#              Adj Close  Total $ Traded
# Date
# 2017-01-03  203.788071    2.057939e+10
# 2017-01-04  205.000443    1.784191e+10
# 2017-01-05  204.837540    1.774501e+10
# 2017-01-06  205.570404    1.625913e+10
# 2017-01-09  204.891876    1.062996e+10

# %%
spy["Total $ Traded"].plot(label='Spy', figsize=(12,6))
tsla["Total $ Traded"].plot(label='Tesla')
aapl["Total $ Traded"].plot(label='Apple')
googl["Total $ Traded"].plot(label='Google')
msft["Total $ Traded"].plot(label='Microsoft')
plt.legend()

# %%
spy['MA5'] = spy['Close'].rolling(5).mean()
aapl['MA5'] = aapl['Close'].rolling(5).mean()
msft['MA5'] = msft['Close'].rolling(5).mean()
googl['MA5'] = googl['Close'].rolling(5).mean()
tsla['MA5'] = tsla['Close'].rolling(5).mean()
spy.tail()
# Out:
#                   High         Low        Open       Close       Volume  \
# Date
# 2022-09-23  370.619995  363.290009  370.579987  367.950012  122210100.0
# 2022-09-26  370.209991  363.029999  366.410004  364.309998   92581200.0
# 2022-09-27  370.399994  360.869995  368.019989  363.380005  108294100.0
# 2022-09-28  372.299988  362.600006  364.380005  370.529999  110802200.0
# 2022-09-29  367.109985  359.700012  366.809998  362.790009  112952300.0
#
#              Adj Close  Total $ Traded         MA9        MA50       MA200  \
# Date
# 2022-09-23  367.950012    4.496721e+10  383.953335  403.041602  422.862301
# 2022-09-26  364.309998    3.372826e+10  380.754445  402.625202  422.336251
# 2022-09-27  363.380005    3.935191e+10  377.285556  402.253802  421.821401
# 2022-09-28  370.529999    4.105554e+10  375.108890  401.819002  421.320351
# 2022-09-29  362.790009    4.097797e+10  372.578891  401.179402  420.801451
#
#                    MA5
# Date
# 2022-09-23  378.440002
# 2022-09-26  373.592004
# 2022-09-27  369.450006
# 2022-09-28  368.078003
# 2022-09-29  365.792004

# %%
spy['MA9'] = spy['Close'].rolling(9).mean()
aapl['MA9'] = aapl['Close'].rolling(9).mean()
msft['MA9'] = msft['Close'].rolling(9).mean()
googl['MA9'] = googl['Close'].rolling(9).mean()
tsla['MA9'] = tsla['Close'].rolling(9).mean()
spy.tail()
# Out:
#                   High         Low        Open       Close       Volume  \
# Date
# 2022-09-23  370.619995  363.290009  370.579987  367.950012  122210100.0
# 2022-09-26  370.209991  363.029999  366.410004  364.309998   92581200.0
# 2022-09-27  370.399994  360.869995  368.019989  363.380005  108294100.0
# 2022-09-28  372.299988  362.600006  364.380005  370.529999  110802200.0
# 2022-09-29  367.109985  359.700012  366.809998  362.790009  112952300.0
#
#              Adj Close  Total $ Traded         MA9        MA50       MA200  \
# Date
# 2022-09-23  367.950012    4.496721e+10  383.953335  403.041602  422.862301
# 2022-09-26  364.309998    3.372826e+10  380.754445  402.625202  422.336251
# 2022-09-27  363.380005    3.935191e+10  377.285556  402.253802  421.821401
# 2022-09-28  370.529999    4.105554e+10  375.108890  401.819002  421.320351
# 2022-09-29  362.790009    4.097797e+10  372.578891  401.179402  420.801451
#
#                    MA5
# Date
# 2022-09-23  378.440002
# 2022-09-26  373.592004
# 2022-09-27  369.450006
# 2022-09-28  368.078003
# 2022-09-29  365.792004

# %%
spy['Close'].plot(label="Closing Prices", figsize=(12,6))
spy['MA9'].plot(label="MA9")
plt.legend()

# %%
spy['MA50'] = spy['Close'].rolling(50).mean()
aapl['MA50'] = aapl['Close'].rolling(50).mean()
msft['MA50'] = msft['Close'].rolling(50).mean()
googl['MA50'] = googl['Close'].rolling(50).mean()
tsla['MA50'] = tsla['Close'].rolling(50).mean()
spy.tail()
# Out:
#                   High         Low        Open       Close       Volume  \
# Date
# 2022-09-23  370.619995  363.290009  370.579987  367.950012  122210100.0
# 2022-09-26  370.209991  363.029999  366.410004  364.309998   92581200.0
# 2022-09-27  370.399994  360.869995  368.019989  363.380005  108294100.0
# 2022-09-28  372.299988  362.600006  364.380005  370.529999  110802200.0
# 2022-09-29  367.109985  359.700012  366.809998  362.790009  112952300.0
#
#              Adj Close  Total $ Traded         MA9        MA50
# Date
# 2022-09-23  367.950012    4.496721e+10  383.953335  403.041602
# 2022-09-26  364.309998    3.372826e+10  380.754445  402.625202
# 2022-09-27  363.380005    3.935191e+10  377.285556  402.253802
# 2022-09-28  370.529999    4.105554e+10  375.108890  401.819002
# 2022-09-29  362.790009    4.097797e+10  372.578891  401.179402

# %%
spy['Close'].plot(label="Closing Prices", figsize=(12,6))
spy['MA50'].plot(label="MA50")
plt.legend()

# %%
spy['MA200'] = spy['Close'].rolling(200).mean()
aapl['MA200'] = aapl['Close'].rolling(200).mean()
msft['MA200'] = msft['Close'].rolling(200).mean()
googl['MA200'] = googl['Close'].rolling(200).mean()
tsla['MA200'] = tsla['Close'].rolling(200).mean()
spy.tail()
# Out:
#                   High         Low        Open       Close       Volume  \
# Date
# 2022-09-23  370.619995  363.290009  370.579987  367.950012  122210100.0
# 2022-09-26  370.209991  363.029999  366.410004  364.309998   92581200.0
# 2022-09-27  370.399994  360.869995  368.019989  363.380005  108294100.0
# 2022-09-28  372.299988  362.600006  364.380005  370.529999  110802200.0
# 2022-09-29  367.109985  359.700012  366.809998  362.790009  112952300.0
#
#              Adj Close  Total $ Traded         MA9        MA50       MA200
# Date
# 2022-09-23  367.950012    4.496721e+10  383.953335  403.041602  422.862301
# 2022-09-26  364.309998    3.372826e+10  380.754445  402.625202  422.336251
# 2022-09-27  363.380005    3.935191e+10  377.285556  402.253802  421.821401
# 2022-09-28  370.529999    4.105554e+10  375.108890  401.819002  421.320351
# 2022-09-29  362.790009    4.097797e+10  372.578891  401.179402  420.801451

# %%
spy['Close'].plot(label="Closing Prices", figsize=(12,6))
spy['MA200'].plot(label="MA200")
plt.legend()

# %%
spy['Close'].plot(label="Closing Prices", figsize=(12,6))
spy['MA5'].plot(label="MA5")
spy['MA9'].plot(label="MA9")
spy['MA50'].plot(label="MA50")
spy['MA200'].plot(label="MA200")
plt.legend()
