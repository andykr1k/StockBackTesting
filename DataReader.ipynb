# %%
import pandas_datareader.data as web
import datetime
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
start = datetime.datetime(2012,1,1)
end = datetime.datetime(2022,9,29)

# %%
googl = web.DataReader("GOOGL", "yahoo", start, end)
aapl = web.DataReader("AAPL", "yahoo", start, end)
tsla = web.DataReader("TSLA", "yahoo", start, end)
msft = web.DataReader("MSFT", "yahoo", start, end)
spy = web.DataReader("SPY", "yahoo", start, end)

# %%
googl.head()
# Out:
#                  High        Low       Open      Close       Volume  Adj Close
# Date
# 2012-01-03  16.720470  16.325577  16.339840  16.651901  146912940.0  16.651901
# 2012-01-04  16.773024  16.532032  16.642391  16.723724  114445440.0  16.723724
# 2012-01-05  16.615866  16.422173  16.569820  16.491741  131184684.0  16.491741
# 2012-01-06  16.516518  16.261011  16.495245  16.266768  107608284.0  16.266768
# 2012-01-09  16.191191  15.546296  16.178679  15.577077  232671096.0  15.577077

# %%
aapl.head()
# Out:
#                  High        Low       Open      Close       Volume  Adj Close
# Date
# 2012-01-03  14.732143  14.607143  14.621429  14.686786  302220800.0  12.540047
# 2012-01-04  14.810000  14.617143  14.642857  14.765714  260022000.0  12.607441
# 2012-01-05  14.948214  14.738214  14.819643  14.929643  271269600.0  12.747402
# 2012-01-06  15.098214  14.972143  14.991786  15.085714  318292800.0  12.880662
# 2012-01-09  15.276786  15.048214  15.196429  15.061786  394024400.0  12.860233

# %%
tsla.head()
# Out:
#                 High       Low      Open     Close      Volume  Adj Close
# Date
# 2012-01-03  1.966667  1.843333  1.929333  1.872000  13921500.0   1.872000
# 2012-01-04  1.911333  1.833333  1.880667  1.847333   9451500.0   1.847333
# 2012-01-05  1.862000  1.790000  1.850667  1.808000  15082500.0   1.808000
# 2012-01-06  1.852667  1.760667  1.813333  1.794000  14794500.0   1.794000
# 2012-01-09  1.832667  1.741333  1.800000  1.816667  13455000.0   1.816667

# %%
msft.head()
# Out:
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2012-01-03  26.959999  26.389999  26.549999  26.770000  64731500.0  21.527195
# 2012-01-04  27.469999  26.780001  26.820000  27.400000  80516100.0  22.033815
# 2012-01-05  27.730000  27.290001  27.379999  27.680000  56081400.0  22.258980
# 2012-01-06  28.190001  27.530001  27.530001  28.110001  99455500.0  22.604759
# 2012-01-09  28.100000  27.719999  28.049999  27.740000  59706800.0  22.307222

# %%
spy.head()
# Out:
#                   High         Low        Open       Close       Volume  \
# Date
# 2012-01-03  128.380005  127.430000  127.760002  127.500000  193697900.0
# 2012-01-04  127.809998  126.709999  127.199997  127.699997  127186500.0
# 2012-01-05  128.229996  126.430000  127.010002  128.039993  173895000.0
# 2012-01-06  128.220001  127.290001  128.199997  127.709999  148050000.0
# 2012-01-09  128.179993  127.410004  128.000000  128.020004   99530200.0
#
#              Adj Close
# Date
# 2012-01-03  104.071907
# 2012-01-04  104.235146
# 2012-01-05  104.512680
# 2012-01-06  104.243301
# 2012-01-09  104.496368

# %%
spy["Close"].plot(label='Spy', figsize=(12,6))
tsla["Close"].plot(label='Tesla')
aapl["Close"].plot(label='Apple')
googl["Close"].plot(label='Google')
msft["Close"].plot(label='Microsoft')
plt.legend()

# %%
spy["Volume"].plot(label='Spy', figsize=(12,6))
tsla["Volume"].plot(label='Tesla')
aapl["Volume"].plot(label='Apple')
googl["Volume"].plot(label='Google')
msft["Volume"].plot(label='Microsoft')
plt.legend()

# %%
spy['Total $ Traded'] = spy['Close'] * spy['Volume']
aapl['Total $ Traded'] = aapl['Close'] * aapl['Volume']
msft['Total $ Traded'] = msft['Close'] * msft['Volume']
googl['Total $ Traded'] = googl['Close'] * googl['Volume']
tsla['Total $ Traded'] = tsla['Close'] * tsla['Volume']
spy.head()
# Out:
#                   High         Low        Open       Close       Volume  \
# Date
# 2012-01-03  128.380005  127.430000  127.760002  127.500000  193697900.0
# 2012-01-04  127.809998  126.709999  127.199997  127.699997  127186500.0
# 2012-01-05  128.229996  126.430000  127.010002  128.039993  173895000.0
# 2012-01-06  128.220001  127.290001  128.199997  127.709999  148050000.0
# 2012-01-09  128.179993  127.410004  128.000000  128.020004   99530200.0
#
#              Adj Close  Total $ Traded
# Date
# 2012-01-03  104.071907    2.469648e+10
# 2012-01-04  104.235146    1.624172e+10
# 2012-01-05  104.512680    2.226551e+10
# 2012-01-06  104.243301    1.890747e+10
# 2012-01-09  104.496368    1.274186e+10

# %%
spy["Total $ Traded"].plot(label='Spy', figsize=(12,6))
tsla["Total $ Traded"].plot(label='Tesla')
aapl["Total $ Traded"].plot(label='Apple')
googl["Total $ Traded"].plot(label='Google')
msft["Total $ Traded"].plot(label='Microsoft')
plt.legend()

# %%
spy['MA5'] = spy['Close'].rolling(5).mean()
aapl['MA5'] = aapl['Close'].rolling(5).mean()
msft['MA5'] = msft['Close'].rolling(5).mean()
googl['MA5'] = googl['Close'].rolling(5).mean()
tsla['MA5'] = tsla['Close'].rolling(5).mean()
spy.tail()
# Out:
#                   High         Low        Open       Close       Volume  \
# Date
# 2022-09-23  370.619995  363.290009  370.579987  367.950012  122210100.0
# 2022-09-26  370.209991  363.029999  366.410004  364.309998   92581200.0
# 2022-09-27  370.399994  360.869995  368.019989  363.380005  108294100.0
# 2022-09-28  372.299988  362.600006  364.380005  370.529999  110802200.0
# 2022-09-29  367.109985  359.700012  366.809998  362.790009  112952300.0
#
#              Adj Close  Total $ Traded         MA5
# Date
# 2022-09-23  367.950012    4.496721e+10  378.440002
# 2022-09-26  364.309998    3.372826e+10  373.592004
# 2022-09-27  363.380005    3.935191e+10  369.450006
# 2022-09-28  370.529999    4.105554e+10  368.078003
# 2022-09-29  362.790009    4.097797e+10  365.792004

# %%
spy['MA9'] = spy['Close'].rolling(9).mean()
aapl['MA9'] = aapl['Close'].rolling(9).mean()
msft['MA9'] = msft['Close'].rolling(9).mean()
googl['MA9'] = googl['Close'].rolling(9).mean()
tsla['MA9'] = tsla['Close'].rolling(9).mean()
spy.tail()
# Out:
#                   High         Low        Open       Close       Volume  \
# Date
# 2022-09-23  370.619995  363.290009  370.579987  367.950012  122210100.0
# 2022-09-26  370.209991  363.029999  366.410004  364.309998   92581200.0
# 2022-09-27  370.399994  360.869995  368.019989  363.380005  108294100.0
# 2022-09-28  372.299988  362.600006  364.380005  370.529999  110802200.0
# 2022-09-29  367.109985  359.700012  366.809998  362.790009  112952300.0
#
#              Adj Close  Total $ Traded         MA5         MA9
# Date
# 2022-09-23  367.950012    4.496721e+10  378.440002  383.953335
# 2022-09-26  364.309998    3.372826e+10  373.592004  380.754445
# 2022-09-27  363.380005    3.935191e+10  369.450006  377.285556
# 2022-09-28  370.529999    4.105554e+10  368.078003  375.108890
# 2022-09-29  362.790009    4.097797e+10  365.792004  372.578891

# %%
spy['Close'].plot(label="Closing Prices", figsize=(12,6))
spy['MA9'].plot(label="MA9")
plt.legend()

# %%
spy['MA50'] = spy['Close'].rolling(50).mean()
aapl['MA50'] = aapl['Close'].rolling(50).mean()
msft['MA50'] = msft['Close'].rolling(50).mean()
googl['MA50'] = googl['Close'].rolling(50).mean()
tsla['MA50'] = tsla['Close'].rolling(50).mean()
spy.tail()
# Out:
#                   High         Low        Open       Close       Volume  \
# Date
# 2022-09-23  370.619995  363.290009  370.579987  367.950012  122210100.0
# 2022-09-26  370.209991  363.029999  366.410004  364.309998   92581200.0
# 2022-09-27  370.399994  360.869995  368.019989  363.380005  108294100.0
# 2022-09-28  372.299988  362.600006  364.380005  370.529999  110802200.0
# 2022-09-29  367.109985  359.700012  366.809998  362.790009  112952300.0
#
#              Adj Close  Total $ Traded         MA5         MA9        MA50
# Date
# 2022-09-23  367.950012    4.496721e+10  378.440002  383.953335  403.041602
# 2022-09-26  364.309998    3.372826e+10  373.592004  380.754445  402.625202
# 2022-09-27  363.380005    3.935191e+10  369.450006  377.285556  402.253802
# 2022-09-28  370.529999    4.105554e+10  368.078003  375.108890  401.819002
# 2022-09-29  362.790009    4.097797e+10  365.792004  372.578891  401.179402

# %%
spy['Close'].plot(label="Closing Prices", figsize=(12,6))
spy['MA50'].plot(label="MA50")
plt.legend()

# %%
spy['MA200'] = spy['Close'].rolling(200).mean()
aapl['MA200'] = aapl['Close'].rolling(200).mean()
msft['MA200'] = msft['Close'].rolling(200).mean()
googl['MA200'] = googl['Close'].rolling(200).mean()
tsla['MA200'] = tsla['Close'].rolling(200).mean()
spy.tail()
# Out:
#                   High         Low        Open       Close       Volume  \
# Date
# 2022-09-23  370.619995  363.290009  370.579987  367.950012  122210100.0
# 2022-09-26  370.209991  363.029999  366.410004  364.309998   92581200.0
# 2022-09-27  370.399994  360.869995  368.019989  363.380005  108294100.0
# 2022-09-28  372.299988  362.600006  364.380005  370.529999  110802200.0
# 2022-09-29  367.109985  359.700012  366.809998  362.790009  112952300.0
#
#              Adj Close  Total $ Traded         MA5         MA9        MA50  \
# Date
# 2022-09-23  367.950012    4.496721e+10  378.440002  383.953335  403.041602
# 2022-09-26  364.309998    3.372826e+10  373.592004  380.754445  402.625202
# 2022-09-27  363.380005    3.935191e+10  369.450006  377.285556  402.253802
# 2022-09-28  370.529999    4.105554e+10  368.078003  375.108890  401.819002
# 2022-09-29  362.790009    4.097797e+10  365.792004  372.578891  401.179402
#
#                  MA200
# Date
# 2022-09-23  422.862301
# 2022-09-26  422.336251
# 2022-09-27  421.821401
# 2022-09-28  421.320351
# 2022-09-29  420.801451

# %%
spy['Close'].plot(label="Closing Prices", figsize=(12,6))
spy['MA200'].plot(label="MA200")
plt.legend()

# %%
spy['Close'].plot(label="Spy Closing Prices", figsize=(16,8))
spy['MA5'].plot(label="MA5")
spy['MA9'].plot(label="MA9")
spy['MA50'].plot(label="MA50")
spy['MA200'].plot(label="MA200")
plt.legend()

# %%
aapl['Close'].plot(label="Apple Closing Prices", figsize=(16,8))
aapl['MA5'].plot(label="MA5")
aapl['MA9'].plot(label="MA9")
aapl['MA50'].plot(label="MA50")
aapl['MA200'].plot(label="MA200")
plt.legend()

# %%
tsla['Close'].plot(label="Tesla Closing Prices", figsize=(16,8))
tsla['MA5'].plot(label="MA5")
tsla['MA9'].plot(label="MA9")
tsla['MA50'].plot(label="MA50")
tsla['MA200'].plot(label="MA200")
plt.legend()

# %%
msft['Close'].plot(label="Microsoft Closing Prices", figsize=(16,8))
msft['MA5'].plot(label="MA5")
msft['MA9'].plot(label="MA9")
msft['MA50'].plot(label="MA50")
msft['MA200'].plot(label="MA200")
plt.legend()

# %%
googl['Close'].plot(label="Google Closing Prices", figsize=(16,8))
googl['MA5'].plot(label="MA5")
googl['MA9'].plot(label="MA9")
googl['MA50'].plot(label="MA50")
googl['MA200'].plot(label="MA200")
plt.legend()

# %%
spy['Close'].plot(label="Spy Closing Prices", figsize=(16,8))
spy['MA200'].plot(label="Spy MA200")
googl['MA200'].plot(label="Google MA200")
tsla['MA200'].plot(label="Tesla MA200")
aapl['MA200'].plot(label="Apple MA200")
msft['MA200'].plot(label="Microsoft MA200")
plt.legend()
