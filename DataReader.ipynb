# %%
import pandas_datareader.data as web
import datetime
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
start = datetime.datetime(2020,1,1)
end = datetime.datetime(2022,10,5)

# %%
googl = web.DataReader("GOOGL", "yahoo", start, end)
aapl = web.DataReader("AAPL", "yahoo", start, end)
tsla = web.DataReader("TSLA", "yahoo", start, end)
msft = web.DataReader("MSFT", "yahoo", start, end)
spy = web.DataReader("SPY", "yahoo", start, end)

# %%
spy.reset_index()
aapl.reset_index()
msft.reset_index()
googl.reset_index()
tsla.reset_index()
# Out:
#           Date        High         Low        Open       Close       Volume  \
# 0   2020-01-02   28.713333   28.114000   28.299999   28.684000  142981500.0
# 1   2020-01-03   30.266666   29.128000   29.366667   29.534000  266677500.0
# 2   2020-01-06   30.104000   29.333332   29.364668   30.102667  151995000.0
# 3   2020-01-07   31.441999   30.224001   30.760000   31.270666  268231500.0
# 4   2020-01-08   33.232666   31.215334   31.580000   32.809334  467164500.0
# ..         ...         ...         ...         ...         ...          ...
# 691 2022-09-29  283.649994  265.779999  282.760010  268.209991   77620600.0
# 692 2022-09-30  275.570007  262.470001  266.149994  265.250000   67517800.0
# 693 2022-10-03  255.160004  241.009995  254.500000  242.399994   98363500.0
# 694 2022-10-04  257.500000  242.009995  250.520004  249.440002  109578500.0
# 695 2022-10-05  246.669998  233.270004  245.009995  240.809998   86982700.0
#
#       Adj Close
# 0     28.684000
# 1     29.534000
# ...

# %%
googl.head()
# Out:
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2020-01-02  68.433998  67.324501  67.420502  68.433998  27278000.0  68.433998
# 2020-01-03  68.687500  67.365997  67.400002  68.075996  23408000.0  68.075996
# 2020-01-06  69.916000  67.550003  67.581497  69.890503  46768000.0  69.890503
# 2020-01-07  70.175003  69.578003  70.023003  69.755501  34330000.0  69.755501
# 2020-01-08  70.592499  69.631500  69.740997  70.251999  35314000.0  70.251999

# %%
aapl.head()
# Out:
#                  High        Low       Open      Close       Volume  Adj Close
# Date
# 2020-01-02  75.150002  73.797501  74.059998  75.087502  135480400.0  73.683578
# 2020-01-03  75.144997  74.125000  74.287498  74.357498  146322800.0  72.967232
# 2020-01-06  74.989998  73.187500  73.447502  74.949997  118387200.0  73.548630
# 2020-01-07  75.224998  74.370003  74.959999  74.597504  108872000.0  73.202728
# 2020-01-08  76.110001  74.290001  74.290001  75.797501  132079200.0  74.380295

# %%
tsla.head()
# Out:
#                  High        Low       Open      Close       Volume  Adj Close
# Date
# 2020-01-02  28.713333  28.114000  28.299999  28.684000  142981500.0  28.684000
# 2020-01-03  30.266666  29.128000  29.366667  29.534000  266677500.0  29.534000
# 2020-01-06  30.104000  29.333332  29.364668  30.102667  151995000.0  30.102667
# 2020-01-07  31.441999  30.224001  30.760000  31.270666  268231500.0  31.270666
# 2020-01-08  33.232666  31.215334  31.580000  32.809334  467164500.0  32.809334

# %%
msft.head()
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2020-01-02  160.729996  158.330002  158.779999  160.619995  22622100.0
# 2020-01-03  159.949997  158.059998  158.320007  158.619995  21116200.0
# 2020-01-06  159.100006  156.509995  157.080002  159.029999  20813700.0
# 2020-01-07  159.669998  157.320007  159.320007  157.580002  21634100.0
# 2020-01-08  160.800003  157.949997  158.929993  160.089996  27746500.0
#
#              Adj Close
# Date
# 2020-01-02  156.591980
# 2020-01-03  154.642136
# 2020-01-06  155.041870
# 2020-01-07  153.628250
# 2020-01-08  156.075302

# %%
spy.head()
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2020-01-02  324.890015  322.529999  323.540009  324.869995  59151200.0
# 2020-01-03  323.640015  321.100006  321.160004  322.410004  77709700.0
# 2020-01-06  323.730011  320.359985  320.489990  323.640015  55653900.0
# 2020-01-07  323.540009  322.239990  323.019989  322.730011  40496400.0
# 2020-01-08  325.779999  322.670013  322.940002  324.450012  68296000.0
#
#              Adj Close
# Date
# 2020-01-02  311.116974
# 2020-01-03  308.761169
# 2020-01-06  309.939117
# 2020-01-07  309.067657
# 2020-01-08  310.714844

# %%
spy["Close"].plot(label='Spy', figsize=(12,6))
tsla["Close"].plot(label='Tesla')
aapl["Close"].plot(label='Apple')
googl["Close"].plot(label='Google')
msft["Close"].plot(label='Microsoft')
plt.legend()

# %%
spy["Volume"].plot(label='Spy', figsize=(12,6))
tsla["Volume"].plot(label='Tesla')
aapl["Volume"].plot(label='Apple')
googl["Volume"].plot(label='Google')
msft["Volume"].plot(label='Microsoft')
plt.legend()

# %%
spy['Total $ Traded'] = spy['Close'] * spy['Volume']
aapl['Total $ Traded'] = aapl['Close'] * aapl['Volume']
msft['Total $ Traded'] = msft['Close'] * msft['Volume']
googl['Total $ Traded'] = googl['Close'] * googl['Volume']
tsla['Total $ Traded'] = tsla['Close'] * tsla['Volume']
spy.head()
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2020-01-02  324.890015  322.529999  323.540009  324.869995  59151200.0
# 2020-01-03  323.640015  321.100006  321.160004  322.410004  77709700.0
# 2020-01-06  323.730011  320.359985  320.489990  323.640015  55653900.0
# 2020-01-07  323.540009  322.239990  323.019989  322.730011  40496400.0
# 2020-01-08  325.779999  322.670013  322.940002  324.450012  68296000.0
#
#              Adj Close  Total $ Traded
# Date
# 2020-01-02  311.116974    1.921645e+10
# 2020-01-03  308.761169    2.505438e+10
# 2020-01-06  309.939117    1.801183e+10
# 2020-01-07  309.067657    1.306940e+10
# 2020-01-08  310.714844    2.215864e+10

# %%
spy["Total $ Traded"].plot(label='Spy', figsize=(12,6))
tsla["Total $ Traded"].plot(label='Tesla')
aapl["Total $ Traded"].plot(label='Apple')
googl["Total $ Traded"].plot(label='Google')
msft["Total $ Traded"].plot(label='Microsoft')
plt.legend()

# %%
spy['MA5'] = spy['Close'].rolling(5).mean()
aapl['MA5'] = aapl['Close'].rolling(5).mean()
msft['MA5'] = msft['Close'].rolling(5).mean()
googl['MA5'] = googl['Close'].rolling(5).mean()
tsla['MA5'] = tsla['Close'].rolling(5).mean()
spy.tail()
# Out:
#                   High         Low        Open       Close       Volume  \
# Date
# 2022-09-29  367.109985  359.700012  366.809998  362.790009  112952300.0
# 2022-09-30  365.910004  357.040009  361.799988  357.179993  153396100.0
# 2022-10-03  368.549988  359.209991  361.079987  366.609985   89756500.0
# 2022-10-04  378.000000  366.570007  372.399994  377.970001  103602800.0
# 2022-10-05  379.459991  370.950012  373.390015  377.089996   88065700.0
#
#              Adj Close  Total $ Traded         MA5
# Date
# 2022-09-29  362.790009    4.097797e+10  365.792004
# 2022-09-30  357.179993    5.479002e+10  363.638000
# 2022-10-03  366.609985    3.290563e+10  364.097998
# 2022-10-04  377.970001    3.915875e+10  367.015997
# 2022-10-05  377.089996    3.320869e+10  368.327997

# %%
spy['MA9'] = spy['Close'].rolling(9).mean()
aapl['MA9'] = aapl['Close'].rolling(9).mean()
msft['MA9'] = msft['Close'].rolling(9).mean()
googl['MA9'] = googl['Close'].rolling(9).mean()
tsla['MA9'] = tsla['Close'].rolling(9).mean()
spy.tail()
# Out:
#                   High         Low        Open       Close       Volume  \
# Date
# 2022-09-29  367.109985  359.700012  366.809998  362.790009  112952300.0
# 2022-09-30  365.910004  357.040009  361.799988  357.179993  153396100.0
# 2022-10-03  368.549988  359.209991  361.079987  366.609985   89756500.0
# 2022-10-04  378.000000  366.570007  372.399994  377.970001  103602800.0
# 2022-10-05  379.459991  370.950012  373.390015  377.089996   88065700.0
#
#              Adj Close  Total $ Traded         MA5         MA9
# Date
# 2022-09-29  362.790009    4.097797e+10  365.792004  372.578891
# 2022-09-30  357.179993    5.479002e+10  363.638000  369.093336
# 2022-10-03  366.609985    3.290563e+10  364.097998  367.151113
# 2022-10-04  377.970001    3.915875e+10  367.015997  367.215556
# 2022-10-05  377.089996    3.320869e+10  368.327997  367.534444

# %%
spy['Close'].plot(label="Closing Prices", figsize=(12,6))
spy['MA9'].plot(label="MA9")
plt.legend()

# %%
spy['MA50'] = spy['Close'].rolling(50).mean()
aapl['MA50'] = aapl['Close'].rolling(50).mean()
msft['MA50'] = msft['Close'].rolling(50).mean()
googl['MA50'] = googl['Close'].rolling(50).mean()
tsla['MA50'] = tsla['Close'].rolling(50).mean()
spy.tail()
# Out:
#                   High         Low        Open       Close       Volume  \
# Date
# 2022-09-29  367.109985  359.700012  366.809998  362.790009  112952300.0
# 2022-09-30  365.910004  357.040009  361.799988  357.179993  153396100.0
# 2022-10-03  368.549988  359.209991  361.079987  366.609985   89756500.0
# 2022-10-04  378.000000  366.570007  372.399994  377.970001  103602800.0
# 2022-10-05  379.459991  370.950012  373.390015  377.089996   88065700.0
#
#              Adj Close  Total $ Traded         MA5         MA9        MA50
# Date
# 2022-09-29  362.790009    4.097797e+10  365.792004  372.578891  401.179402
# 2022-09-30  357.179993    5.479002e+10  363.638000  369.093336  400.347202
# 2022-10-03  366.609985    3.290563e+10  364.097998  367.151113  399.777602
# 2022-10-04  377.970001    3.915875e+10  367.015997  367.215556  399.425602
# 2022-10-05  377.089996    3.320869e+10  368.327997  367.534444  399.149601

# %%
spy['Close'].plot(label="Closing Prices", figsize=(12,6))
spy['MA50'].plot(label="MA50")
plt.legend()

# %%
spy['MA200'] = spy['Close'].rolling(200).mean()
aapl['MA200'] = aapl['Close'].rolling(200).mean()
msft['MA200'] = msft['Close'].rolling(200).mean()
googl['MA200'] = googl['Close'].rolling(200).mean()
tsla['MA200'] = tsla['Close'].rolling(200).mean()
spy.tail()
# Out:
#                   High         Low        Open       Close       Volume  \
# Date
# 2022-09-29  367.109985  359.700012  366.809998  362.790009  112952300.0
# 2022-09-30  365.910004  357.040009  361.799988  357.179993  153396100.0
# 2022-10-03  368.549988  359.209991  361.079987  366.609985   89756500.0
# 2022-10-04  378.000000  366.570007  372.399994  377.970001  103602800.0
# 2022-10-05  379.459991  370.950012  373.390015  377.089996   88065700.0
#
#              Adj Close  Total $ Traded         MA5         MA9        MA50  \
# Date
# 2022-09-29  362.790009    4.097797e+10  365.792004  372.578891  401.179402
# 2022-09-30  357.179993    5.479002e+10  363.638000  369.093336  400.347202
# 2022-10-03  366.609985    3.290563e+10  364.097998  367.151113  399.777602
# 2022-10-04  377.970001    3.915875e+10  367.015997  367.215556  399.425602
# 2022-10-05  377.089996    3.320869e+10  368.327997  367.534444  399.149601
#
#                  MA200
# Date
# 2022-09-29  420.801451
# ...

# %%
spy['Close'].plot(label="Closing Prices", figsize=(12,6))
spy['MA200'].plot(label="MA200")
plt.legend()

# %%
spy['Close'].plot(label="Spy Closing Prices", figsize=(16,8))
spy['MA5'].plot(label="MA5")
spy['MA9'].plot(label="MA9")
spy['MA50'].plot(label="MA50")
spy['MA200'].plot(label="MA200")
plt.legend()

# %%
aapl['Close'].plot(label="Apple Closing Prices", figsize=(16,8))
aapl['MA5'].plot(label="MA5")
aapl['MA9'].plot(label="MA9")
aapl['MA50'].plot(label="MA50")
aapl['MA200'].plot(label="MA200")
plt.legend()

# %%
tsla['Close'].plot(label="Tesla Closing Prices", figsize=(16,8))
tsla['MA5'].plot(label="MA5")
tsla['MA9'].plot(label="MA9")
tsla['MA50'].plot(label="MA50")
tsla['MA200'].plot(label="MA200")
plt.legend()

# %%
msft['Close'].plot(label="Microsoft Closing Prices", figsize=(16,8))
msft['MA5'].plot(label="MA5")
msft['MA9'].plot(label="MA9")
msft['MA50'].plot(label="MA50")
msft['MA200'].plot(label="MA200")
plt.legend()

# %%
googl['Close'].plot(label="Google Closing Prices", figsize=(16,8))
googl['MA5'].plot(label="MA5")
googl['MA9'].plot(label="MA9")
googl['MA50'].plot(label="MA50")
googl['MA200'].plot(label="MA200")
plt.legend()

# %%
spy['Close'].plot(label="Spy Closing Prices", figsize=(16,8))
spy['MA200'].plot(label="Spy MA200")
googl['MA200'].plot(label="Google MA200")
tsla['MA200'].plot(label="Tesla MA200")
aapl['MA200'].plot(label="Apple MA200")
msft['MA200'].plot(label="Microsoft MA200")
plt.legend()

# %%
spy['Close'].plot(label="Spy Closing Prices", figsize=(16,8))
spy['MA200'].plot(label="Spy MA200")
spy['MA50'].plot(label="Spy MA50")
spy['MA9'].plot(label="Spy MA9")
googl['MA200'].plot(label="Google MA200")
googl['MA50'].plot(label="Google MA50")
googl['MA9'].plot(label="Google MA9")
tsla['MA200'].plot(label="Tesla MA200")
tsla['MA50'].plot(label="Tesla MA50")
tsla['MA9'].plot(label="Tesla MA9")
aapl['MA200'].plot(label="Apple MA200")
aapl['MA50'].plot(label="Apple MA50")
aapl['MA9'].plot(label="Apple MA9")
msft['MA200'].plot(label="Microsoft MA200")
msft['MA50'].plot(label="Microsoft MA50")
msft['MA9'].plot(label="Microsoft MA9")
plt.legend()

# %%
spy['Close'].plot(label="Spy Closing Prices", figsize=(16,8))
spy['MA200'].plot(label="Spy MA200")
spy['MA50'].plot(label="Spy MA50")
googl['MA200'].plot(label="Google MA200")
googl['MA50'].plot(label="Google MA50")
tsla['MA200'].plot(label="Tesla MA200")
tsla['MA50'].plot(label="Tesla MA50")
aapl['MA200'].plot(label="Apple MA200")
aapl['MA50'].plot(label="Apple MA50")
msft['MA200'].plot(label="Microsoft MA200")
msft['MA50'].plot(label="Microsoft MA50")
plt.legend()

# %%
spy['RVOL'] = spy['Volume'] / spy['MA50']
aapl['RVOL'] = aapl['Volume'] / aapl['MA50']
msft['RVOL'] = msft['Volume'] / msft['MA50']
googl['RVOL'] = googl['Volume'] / googl['MA50']
tsla['RVOL'] = tsla['Volume'] / tsla['MA50']
spy.tail()
# Out:
#                   High         Low        Open       Close       Volume  \
# Date
# 2022-09-29  367.109985  359.700012  366.809998  362.790009  112952300.0
# 2022-09-30  365.910004  357.040009  361.799988  357.179993  153396100.0
# 2022-10-03  368.549988  359.209991  361.079987  366.609985   89756500.0
# 2022-10-04  378.000000  366.570007  372.399994  377.970001  103602800.0
# 2022-10-05  379.459991  370.950012  373.390015  377.089996   88065700.0
#
#              Adj Close  Total $ Traded         MA5         MA9        MA50  \
# Date
# 2022-09-29  362.790009    4.097797e+10  365.792004  372.578891  401.179402
# 2022-09-30  357.179993    5.479002e+10  363.638000  369.093336  400.347202
# 2022-10-03  366.609985    3.290563e+10  364.097998  367.151113  399.777602
# 2022-10-04  377.970001    3.915875e+10  367.015997  367.215556  399.425602
# 2022-10-05  377.089996    3.320869e+10  368.327997  367.534444  399.149601
#
#                  MA200           RVOL
# Date
# ...

# %%
spy['Close'].plot(label="Spy Closing Prices", figsize=(16,8))
spy['MA200'].plot(label="Spy MA200")
spy['MA50'].plot(label="Spy MA50")
plt.legend()
plt.figure()
spy['RVOL'].plot(label="Spy RVOL", figsize=(16,4))
plt.legend()

# %%
aapl['Close'].plot(label="Apple Closing Prices", figsize=(16,6))
aapl['MA200'].plot(label="Apple MA200")
aapl['MA50'].plot(label="Apple MA50")
plt.legend()
plt.figure()
aapl['RVOL'].plot(label="Apple RVOL", figsize=(16,4))
plt.legend()

# %%
spy['% Change'] = (spy['Close']/spy['Open']) / spy['Open'] * 100
spy['Range'] = (abs(spy['High']-spy['Low']))
spy.tail()
# Out:
#                   High         Low        Open       Close       Volume  \
# Date
# 2022-09-29  367.109985  359.700012  366.809998  362.790009  112952300.0
# 2022-09-30  365.910004  357.040009  361.799988  357.179993  153396100.0
# 2022-10-03  368.549988  359.209991  361.079987  366.609985   89756500.0
# 2022-10-04  378.000000  366.570007  372.399994  377.970001  103602800.0
# 2022-10-05  379.459991  370.950012  373.390015  377.089996   88065700.0
#
#              Adj Close  Total $ Traded         MA5         MA9        MA50  \
# Date
# 2022-09-29  362.790009    4.097797e+10  365.792004  372.578891  401.179402
# 2022-09-30  357.179993    5.479002e+10  363.638000  369.093336  400.347202
# 2022-10-03  366.609985    3.290563e+10  364.097998  367.151113  399.777602
# 2022-10-04  377.970001    3.915875e+10  367.015997  367.215556  399.425602
# 2022-10-05  377.089996    3.320869e+10  368.327997  367.534444  399.149601
#
#                  MA200           RVOL  % Change      Range
# Date
# ...

# %%
for items in spy:
    if (spy.iloc[items]['Low'] > spy.iloc[items - 1]['Low'] and spy.iloc[items]['High'] < spy.iloc[items - 1]['High']):
        spy['Strat'] = "Inside"
    elif (spy.iloc[items]['Low'] < spy.iloc[items - 1]['Low'] and spy.iloc[items]['High'] > spy.iloc[items - 1]['High']):
        spy['Strat'] = "Outside"
    elif (spy.iloc[items]['Low'] > spy.iloc[items - 1]['Low'] and spy.iloc[items]['High'] > spy.iloc[items - 1]['High']):
        spy['Strat'] = "Upside"
    elif (spy.iloc[items]['Low'] < spy.iloc[items - 1]['Low'] and spy.iloc[items]['High'] < spy.iloc[items - 1]['High']):
        spy['Strat'] = "Downside"
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [175], line 2
#       1 for items in spy:
# ----> 2     if (spy.iloc[int(float(items))]['Low'] > spy.iloc[items - 1]['Low'] and spy.iloc[items]['High'] < spy.iloc[items - 1]['High']):
#       3         spy['Strat'] = "Inside"
#       4     elif (spy.iloc[items]['Low'] < spy.iloc[items - 1]['Low'] and spy.iloc[items]['High'] > spy.iloc[items - 1]['High']):
#
# ValueError: could not convert string to float: 'High'
