# %%
import pandas as pd
import numpy as np
import matplotlib
# %matplotlib inline

df = pd.read_csv("AAPL.csv")
dp = pd.read_csv("Dividends.csv")
print(dp.Dividends[0])
print(type(dp.Dividends[0]))

print(df.AdjClose[0])
print(type(df.AdjClose[0]))
# Out:
# 0.094643
# <class 'numpy.float64'>
# 12.540045
# <class 'numpy.float64'>

# %%
adj = df.Close
adj.plot()
# Out:
# <AxesSubplot:>
